# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_json('https://www.mohfw.gov.in/data/datanew.json')
# Reading dataset

# %%
df
# Loading dataset
# Out:
#     sno                                state_name  active  positive     cured  \
# 0     1               Andaman and Nicobar Islands      43     10261     10089
# 1     2                            Andhra Pradesh    2042   2324796   2308021
# 2     3                         Arunachal Pradesh     211     64747     64240
# 3     4                                     Assam    2185    727319    717143
# 4     5                                     Bihar    2345    836573    821963
# 5     6                                Chandigarh     393     94517     92959
# 6     7                              Chhattisgarh    1900   1156904   1140959
# 7     8  Dadra and Nagar Haveli and Daman and Diu       7     11501     11490
# 8     9                                     Delhi    1960   1941415   1913170
# 9    10                                       Goa     832    250135    245460
# 10   11                                   Gujarat    4156   1239009   1223903
# 11   12                                   Haryana    1622   1020319   1008067
# 12   13                          Himachal Pradesh    1350    288135    282641
# 13   14                         Jammu and Kashmir     738    456151    450655
# 14   15                                 Jharkhand     800    437002    430879
# 15   16                                 Karnataka    6419   3980585   3934041
# 16   17                                 Kerala***   25683   6677772   6581919
# 17   18                                    Ladakh      51     28578     28299
# 18   19                               Lakshadweep       0     11412     11360
# 19   20                            Madhya Pradesh     857   1045779   1034176
# 20   21                               Maharashtra   17567   8007648   7842090
# 21   22                                   Manipur     216    137543    135207
# 22   23                                 Meghalaya     115     94146     92436
# 23   24                                   Mizoram     871    230124    228547
# 24   25                                  Nagaland      34     35555     34759
# 25   26                                    Odisha    3188   1294585   1282270
# 26   27                                Puducherry     915    167879    165002
# 27   28                                    Punjab    1210    765017    746021
# 28   29                                 Rajasthan    1212   1289966   1279182
# 29   30                                    Sikkim     253     39537     38826
# 30   31                                Tamil Nadu   18710   3506257   3449519
# 31   32                                 Telangana    5112    807134    797911
# 32   33                                   Tripura     387    101330    100020
# 33   34                               Uttarakhand     868    439334    430769
# 34   35                             Uttar Pradesh    2325   2094600   2068727
# 35   36                               West Bengal   25880   2056285   2009154
# 36   37                                            132457  43669850  43011874
#
#      death  new_active  new_positive  new_cured  new_death death_reconsille  \
# 0      129          46         10270      10095        129
# 1    14733        2121       2325203    2308349      14733
# 2      296         205         64792      64291        296
# 3     7991        2584        727909     717333       7992
# 4    12265        2511        837138     822361      12266
# 5     1165         408         94589      93016       1165
# 6    14045        2068       1157290    1141177      14045
# 7        4           9         11505      11492          4
# 8    26285        1966       1941905    1913651      26288
# 9     3843         813        250265     245608       3844
# 10   10950        4225       1239751    1224576      10950
# 11   10630        1601       1020684    1008453      10630
# 12    4144        1580        288493     282769       4144
# 13    4758         769        456291     450764       4758
# 14    5323         888        437191     430980       5323
# 15   40125        6603       3981816    3935088      40125
# 16   70186       26451       6681317    6584680      70186               16
# 17     228          49         28588      28311        228
# 18      52           0         11412      11360         52
# 19   10746         901       1045950    1034303      10746
# 20  147991       16922       8010223    7845300     148001
# 21    2120         268        137613     135225       2120
# 22    1595         131         94167      92441       1595
# 23     706         964        230229     228559        706
# 24     762          42         35566      34762        762
# 25    9127        3511       1295328    1282690       9127
# 26    1962         915        168053     165176       1962
# 27   17786        1260        765273     746227      17786
# 28    9572        1265       1290153    1279316       9572
# 29     458         310         39605      38837        458
# 30   38028       18282       3508526    3452216      38028
# 31    4111        5082        807661     798468       4111
# 32     923         584        101544     100037        923
# 33    7697         883        439404     430823       7698
# 34   23548        2363       2095021    2069109      23549
# 35   21251       27496       2059264    2010513      21255
# 36  525519      136076      43689989   43028356     525557               16
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3      1          18
# 4      1          10
# 5                  4
# 6                 22
# 7                 26
# 8      3           7
# 9      1          30
# 10                24
# 11                 6
# 12                 2
# 13                 1
# 14                20
# 15                29
# 16    16          32
# 17                37
# 18                31
# 19                23
# 20    10          27
# 21                14
# 22                17
# 23                15
# 24                13
# 25                21
# 26                34
# 27                 3
# 28                 8
# 29                11
# 30                33
# 31                36
# 32                16
# 33     1           5
# 34     1           9
# 35     4          19
# 36    38           0

# %%
df.shape
# There are 37 rows and 11 columns
# Out:
# (37, 13)

# %%
df.isnull().sum()
# no null values
# Out:
# sno                 0
# state_name          0
# active              0
# positive            0
# cured               0
# death               0
# new_active          0
# new_positive        0
# new_cured           0
# new_death           0
# death_reconsille    0
# total               0
# state_code          0
# dtype: int64

# %%
df.info()
# type of data present in the columns(int,object)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   sno               37 non-null     int64
#  1   state_name        37 non-null     object
#  2   active            37 non-null     int64
#  3   positive          37 non-null     int64
#  4   cured             37 non-null     int64
#  5   death             37 non-null     int64
#  6   new_active        37 non-null     int64
#  7   new_positive      37 non-null     int64
#  8   new_cured         37 non-null     int64
#  9   new_death         37 non-null     int64
#  10  death_reconsille  37 non-null     object
#  11  total             37 non-null     object
#  12  state_code        37 non-null     int64
# dtypes: int64(10), object(3)
# memory usage: 3.9+ KB

# %%
df.describe()
# Viewing the descriptive statistics of the data like mean, std deviation, min and max values present in the dataset
# Out:
#              sno         active      positive         cured          death  \
# count  37.000000      37.000000  3.700000e+01  3.700000e+01      37.000000
# mean   19.000000    7159.837838  2.360532e+06  2.324966e+06   28406.864865
# std    10.824355   22218.027833  7.201888e+06  7.092474e+06   88118.527487
# min     1.000000       0.000000  1.026100e+04  1.008900e+04       4.000000
# 25%    10.000000     387.000000  1.013300e+05  1.000200e+05    1165.000000
# 50%    19.000000    1210.000000  7.273190e+05  7.171430e+05    7697.000000
# 75%    28.000000    2345.000000  1.294585e+06  1.282270e+06   14733.000000
# max    37.000000  132457.000000  4.366985e+07  4.301187e+07  525519.000000
#
#           new_active  new_positive     new_cured      new_death  state_code
# count      37.000000  3.700000e+01  3.700000e+01      37.000000   37.000000
# mean     7355.459459  2.361621e+06  2.325857e+06   28408.486486   18.324324
# std     22813.460663  7.205187e+06  7.095207e+06   88124.820920   11.212726
# min         0.000000  1.027000e+04  1.009500e+04       4.000000    0.000000
# 25%       408.000000  1.015440e+05  1.000370e+05    1165.000000    9.000000
# 50%      1260.000000  7.279090e+05  7.173330e+05    7698.000000   18.000000
# 75%      2584.000000  1.295328e+06  1.282690e+06   14733.000000   28.000000
# max    136076.000000  4.368999e+07  4.302836e+07  525557.000000   37.000000

# %%
df.keys()
# Displaying all the column names present in data
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.columns
# Different code but same purpose as above that is displaying all column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.nunique()
# The nunique() function is used to count distinct observations over requested axis. It returns Series with number of distinct observations.
# Out:
# sno                 37
# state_name          37
# active              37
# positive            37
# cured               37
# death               37
# new_active          37
# new_positive        37
# new_cured           37
# new_death           37
# death_reconsille     2
# total                7
# state_code          37
# dtype: int64

# %%
df.tail()
# As we can see there is an extra row in the end that may be the total of that column
# Out:
#     sno     state_name  active  positive     cured   death  new_active  \
# 32   33        Tripura     387    101330    100020     923         584
# 33   34    Uttarakhand     868    439334    430769    7697         883
# 34   35  Uttar Pradesh    2325   2094600   2068727   23548        2363
# 35   36    West Bengal   25880   2056285   2009154   21251       27496
# 36   37                 132457  43669850  43011874  525519      136076
#
#     new_positive  new_cured  new_death death_reconsille total  state_code
# 32        101544     100037        923                                 16
# 33        439404     430823       7698                      1           5
# 34       2095021    2069109      23549                      1           9
# 35       2059264    2010513      21255                      4          19
# 36      43689989   43028356     525557               16    38           0

# %%
df=df.iloc[:36]
# we apply the iloc function and select all rows except the last row

# %%
df
# This is the dataset that we are to work on
# Out:
#     sno                                state_name  active  positive    cured  \
# 0     1               Andaman and Nicobar Isl
#
#    total  state_code
# 0                 35
# 1                 28
# 2                 12
# 3      1          18
# 4      1          10
# 5                  4
# 6                 22
# 7                 26
# 8      3           7
# 9      1          30
# 10                24
# 11                 6
# 12                 2
# 13                 1
# 14                20
# 15                29
# 16    16          32
# 17                37
# 18                31
# 19                23
# 20    10          27
# 21                14
# 22                17
# 23                15
# 24                13
# 25                21
# 26                34
# 27                 3
# 28                 8
# 29                11
# 30                33
# 31                36
# 32                16
# 33     1           5
# 34     1           9
# 35     4          19

# %%
df['active'].sum(axis = 0) 
# The total number of active cases in India is 2,22,526
# Out:
# 132457

# %%
df['positive'].sum(axis = 0) 
# The total number of positive cases in India are 10,466,595
# Out:
# 43669850

# %%
df['cured'].sum(axis = 0)
# The total number of cured cases in India is 10,092,909
# Out:
# 43011874

# %%
df['death'].sum(axis = 0)
# The total number of deaths in India are 1,51,160
# Out:
# 525535

# %%
df['new_active'].sum(axis = 0)
# The total number of new active cases are 2,16,558
# Out:
# 136076

# %%
df['new_positive'].sum(axis = 0)
# The total number of new positive cases are 10,479,179
# Out:
# 43689989

# %%
df['new_cured'].sum(axis = 0)
# The total number of new cured cases are 10,111,294
# Out:
# 43028356

# %%
df['new_death'].sum(axis = 0)
# The total number of new death cases are 1,51,327
# Out:
# 525557

# %% [markdown]
# ### Data Visualization

# %%
sns.pairplot(data=df)
# plotting scatter plots of all data using pairplot

# %%
cases_df=df.sum()
# Storing total cases in cases_df

# %%
cases_df
# Subset of original dataset
# Out:
# sno                                                               666
# state_name          Andaman and Nicobar IslandsAndhra PradeshAruna...
# active                                                         132457
# positive                                                     43669850
# cured                                                        43011874
# death                                                          525535
# new_active                                                     136076
# new_positive                                                 43689989
# new_cured                                                    43028356
# new_death                                                      525557
# death_reconsille                                                   16
# total                                                     11311610114
# state_code                                                        678
# dtype: object

# %%
cases_df.drop(['sno','state_name','state_code'],inplace=True)
# Dropping unnecessary columns

# %%
cases_df
# Name of case types and their total number
# Out:
# active                   132457
# positive               43669850
# cured                  43011874
# death                    525535
# new_active               136076
# new_positive           43689989
# new_cured              43028356
# new_death                525557
# death_reconsille             16
# total               11311610114
# dtype: object

# %%
my_data = [222526,10466595,10092909,151160]
my_labels = 'Active','Positive','Cured','Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [216558,10479179,10111294,151327]
my_labels = 'New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,1.5)
my_colors = ['lightblue','lightsteelblue','lightpink','black']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
my_data = [222526,10466595,10092909,151160,216558,10479179,10111294,151327]
my_labels = 'Active','Positive','Cured','Death','New Active','New Positive','New Cured','New Death'
my_explode = (0,0,0,0,0,0,0,1.5)
my_colors = ['gray','navajowhite','blanchedalmond','grey','lightblue','papayawhip','moccasin','lightpink']
fig1, ax1 = plt.subplots(figsize=(13, 8))
plt.pie(my_data, labels=my_labels, autopct='%1.1f%%', startangle=15, shadow = True, colors=my_colors, explode=my_explode)
plt.axis('equal')
plt.show()
# Pie chart visualization

# %%
plt.rcParams['figure.figsize']=(13,8)
# giving figure size

# %%
df[['state_name','active']].groupby(["state_name"]).mean().sort_values(by='active').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their active level of cases.
# Kerela has a higher active cases compared to other states

# %%
df[['state_name','death']].groupby(["state_name"]).mean().sort_values(by='death').plot.bar(color='purple')
plt.show()
# We can also use the groupby function to sort values in an ascending order based on the x-axis, y-axis and its keys
# Below we get a clear picture of the states in an increasing order based on their death cases.
# Maharashtra has a higher death cases compared to other states

# %%
df.columns
# Displaying column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='active',color='teal',data=df);
# The visualization below shows us that high number of active cases are found in kerala followed by maharashtra

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='positive',color='teal',data=df);
# The below visualization shows us that high number of positive cases can be seen in Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='cured',color='teal',data=df);
# The visualization below shows us that high number of people have cured in the state of Maharashtra followed by karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='death',color='teal',data=df);
# The below visualization shows us that high number of deaths taking place in the state of Maharashtra followed by Tamilnadu and karnataka

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_active',color='teal',data=df);
# The following visualization shows us the total number of new cases and kerela has the high number of new active cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_positive',color='teal',data=df);
# The following visualization shows us the total number of new positive cases and Maharashtra has the high number of new positive cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_cured',color='teal',data=df);
# The following visualization shows us the total number of new cured cases and Maharashtra has the high number of new cured cases

# %%
plt.figure(figsize=(13, 8))
plt.xticks(rotation=90)
sns.barplot(x='state_name',y='new_death',color='teal',data=df);
# Maharashtra has the highest new death rates in India followed by Karnataka

# %%
df.columns
# column names
# Out:
# Index(['sno', 'state_name', 'active', 'positive', 'cured', 'death',
#        'new_active', 'new_positive', 'new_cured', 'new_death',
#        'death_reconsille', 'total', 'state_code'],
#       dtype='object')

# %%
df.drop(['sno','state_code'],axis=1,inplace=True)
# we have dropped columns like sno and statecode
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:4913: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
df.head(5)
# This is the resulting data
# Out:
#                     state_name  active  positive    cured  death  new_active  \
# 0  Andaman and Nicobar Islands      43     10261    10089    129          46
# 1               Andhra Pradesh    2042   2324796  2308021  14733        2121
# 2            Arunachal Pradesh     211     64747    64240    296         205
# 3                        Assam    2185    727319   717143   7991        2584
# 4                        Bihar    2345    836573   821963  12265        2511
#
#    new_positive  new_cured  new_death death_reconsille total
# 0         10270      10095        129
# 1       2325203    2308349      14733
# 2         64792      64291        296
# 3        727909     717333       7992                      1
# 4        837138     822361      12266                      1

# %%
df=df.set_index('state_name')
# Setting index as statename

# %%
df.head(5)
# Out:
#                              active  positive    cured  death  new_active  \
# state_name
# Andaman and Nicobar Islands      43     10261    10089    129          46
# Andhra Pradesh                 2042   2324796  2308021  14733        2121
# Arunachal Pradesh               211     64747    64240    296         205
# Assam                          2185    727319   717143   7991        2584
# Bihar                          2345    836573   821963  12265        2511
#
#                              new_positive  new_cured  new_death  \
# state_name
# Andaman and Nicobar Islands         10270      10095        129
# Andhra Pradesh                    2325203    2308349      14733
# Arunachal Pradesh                   64792      64291        296
# Assam                              727909     717333       7992
# Bihar                              837138     822361      12266
#
#                             death_reconsille total
# state_name
# Andaman and Nicobar Islands
# Andhra Pradesh
# Arunachal Pradesh
# Assam                                            1
# Bihar                                            1

# %%
df.plot.barh(stacked=True,figsize=(13,8))
# Stacked bar plot

# %%
df1=df[['cured', 'death']] 
df1.plot.barh(color={"cured": "purple", "death": "black"},figsize=(13,8))
# bar plot for cured and death

# %%
df2=df[['positive', 'death']] 
df2.plot.barh(color={"positive": "aquamarine", "death": "orange"},figsize=(13,8))
# bar plot for positive cases and death rate

# %%
df3=df[['death', 'cured']] 
df3.plot.barh(color={"death": "red", "cured": "grey"},figsize=(13,8))
# barplot for death cases and cured cases

# %%
df4=df[['active', 'death']] 
df4.plot.barh(color={"active": "black", "death": "orange"},figsize=(13,8))
# bar plot for active and death cases
